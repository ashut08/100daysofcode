# %%
import gym 
import numpy as np

# %%
env=gym.make('FrozenLake-v0')

# %%
for i in range(20):
    env.reset()
    for t in range(100):
        env.render()
        env.step(env.action_space.sample())
# Out:
# ---------------------------------------------------------------------------
# NoSuchDisplayException                    Traceback (most recent call last)
# <ipython-input-3-bdb9221780d9> in <module>
#       2     env.reset()
#       3     for t in range(100):
# ----> 4         env.render()
#       5         env.step(env.action_space.sample())
#
# ~/anaconda3/envs/cnn/lib/python3.8/site-packages/gym/core.py in render(self, mode, **kwargs)
#     231
#     232     def render(self, mode='human', **kwargs):
# --> 233         return self.env.render(mode, **kwargs)
#     234
#     235     def close(self):
#
# ~/anaconda3/envs/cnn/lib/python3.8/site-packages/gym/envs/classic_control/mountain_car.py in render(self, mode)
#      76
#      77         if self.viewer is None:
# ---> 78             from gym.envs.classic_control import rendering
#      79             self.viewer = rendering.Viewer(screen_width, screen_height)
# ...
