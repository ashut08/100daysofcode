# %% [markdown]
# # Pre-processing data

# %% [markdown]
# ## Converting  data type

# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
df=pd.read_csv('artwork_sample.csv')
# Out:
# /root/anaconda3/envs/tensorflow/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head(10)
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
# 5  1040           A00006  Blake, William     artist        39
# 6  1041           A00007  Blake, William     artist        39
# 7  1042           A00008  Blake, William     artist        39
# 8  1043           A00009  Blake, William     artist        39
# 9  1044           A00010  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           id accession_number                             artist artistRole  \
# 0       1035           A00001                      Blake, Robert     artist
# 1       1036           A00002                      Blake, Robert     artist
# 2       1037           A00003                      Blake, Robert     artist
# 3       1038           A00004                      Blake, Robert     artist
# 4       1039           A00005                     Blake, William     artist
# ...      ...              ...                                ...        ...
# 42498  11910           N03973               Pinwell, George John     artist
# 42499   1784           N03975  Burne-Jones, Sir Edward Coley, Bt     artist
# 42500   1785           N03976  Burne-Jones, Sir Edward Coley, Bt     artist
# 42501   1786           N03977  Burne-Jones, Sir Edward Coley, Bt     artist
# 42502   1787           N03978  Burne-Jones, Sir Edward Coley, Bt     artist
#
# ...

# %%
import numpy as np

# %%
df.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                  float64
# acquisitionYear       float64
# dimensions             object
# width                  object
# height                 object
# depth                 float64
# units                  object
# inscription            object
# thumbnailCopyright     object
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
df.height
# Out:
# 0        419
# 1        213
# 2        467
# 3        394
# 4        335
#         ...
# 42498    127
# 42499    165
# 42500    178
# 42501    165
# 42502    NaN
# Name: height, Length: 42503, dtype: object

# %% [markdown]
# ## convert height into float datatpe

# %%
pd.to_numeric(df.height,errors='coerce')
# Out:
# 0        419.0
# 1        213.0
# 2        467.0
# 3        394.0
# 4        335.0
#          ...
# 42498    127.0
# 42499    165.0
# 42500    178.0
# 42501    165.0
# 42502      NaN
# Name: height, Length: 42503, dtype: float64

# %%
df.height[42502]
# Out:
# nan

# %%
df.height=pd.to_numeric(df.height,errors='coerce')

# %%
df.height.dtype
# Out:
# dtype('float64')

# %%
df.height.min()
# Out:
# 21.0

# %%
df.height.max()
# Out:
# 14850.0

# %%
df.height.mean()
# Out:
# 210.93723451003368

# %% [markdown]
# ## Normalizing  Height

# %%
df.height.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Normmalization method
#
# <b>Min-max normalization </b>is one of the most common ways to normalize data. For every feature, the minimum value of that feature gets transformed into a 0, the maximum value gets transformed into a 1, and every other value gets transformed into a decimal between 0 and 1.
#
# <b>Formula =</b> vlaue-min/max-min
#
#
# <b>Z-SCORE NORMALIZATION</b> Z-score normalization is a strategy of normalizing data that avoids this outlier issue. The formula for Z-score normalization is below:
#      value-μ/σ
# ​
# ​

# %%
height=df.height

# %% [markdown]
# ## normalized by z-score

# %%
norm=(height -height.mean())/height.std()

# %%
norm
# Out:
# 0        0.794682
# 1        0.007879
# 2        0.978014
# 3        0.699196
# 4        0.473849
#            ...
# 42498   -0.320593
# 42499   -0.175454
# 42500   -0.125802
# 42501   -0.175454
# 42502         NaN
# Name: height, Length: 42503, dtype: float64

# %% [markdown]
# ### by min max normalized

# %%
minmax=(height-height.mean())/(height.max()-height.mean())

# %%
minmax
# Out:
# 0        0.014213
# 1        0.000141
# 2        0.017492
# 3        0.012505
# 4        0.008475
#            ...
# 42498   -0.005734
# 42499   -0.003138
# 42500   -0.002250
# 42501   -0.003138
# 42502         NaN
# Name: height, Length: 42503, dtype: float64

# %%
minmax.min()
# Out:
# -0.012974685439411496

# %%
minmax.max()
# Out:
# 1.0

# %%
df.height
# Out:
# 0        419.0
# 1        213.0
# 2        467.0
# 3        394.0
# 4        335.0
#          ...
# 42498    127.0
# 42499    165.0
# 42500    178.0
# 42501    165.0
# 42502      NaN
# Name: height, Length: 42503, dtype: float64

# %%
df.height=minmax

# %%
df['std_height']=norm

# %%
df.height
# Out:
# 0        0.014213
# 1        0.000141
# 2        0.017492
# 3        0.012505
# 4        0.008475
#            ...
# 42498   -0.005734
# 42499   -0.003138
# 42500   -0.002250
# 42501   -0.003138
# 42502         NaN
# Name: height, Length: 42503, dtype: float64

# %% [markdown]
# ### Transforming data

# %%
df.height.transform(lambda x: x)
# Out:
# 0        0.014213
# 1        0.000141
# 2        0.017492
# 3        0.012505
# 4        0.008475
#            ...
# 42498   -0.005734
# 42499   -0.003138
# 42500   -0.002250
# 42501   -0.003138
# 42502         NaN
# Name: height, Length: 42503, dtype: float64

# %%
df.height.transform(lambda x: x/10)
# Out:
# 0        0.001421
# 1        0.000014
# 2        0.001749
# 3        0.001251
# 4        0.000847
#            ...
# 42498   -0.000573
# 42499   -0.000314
# 42500   -0.000225
# 42501   -0.000314
# 42502         NaN
# Name: height, Length: 42503, dtype: float64

# %%
df
# Out:
#           id accession_number                             artist artistRole  \
# 0       1035           A00001                      Blake, Robert     artist
# 1       1036           A00002                      Blake, Robert     artist
# 2       1037           A00003                      Blake, Robert     artist
# 3       1038           A00004                      Blake, Robert     artist
# 4       1039           A00005                     Blake, William     artist
# ...      ...              ...                                ...        ...
# 42498  11910           N03973               Pinwell, George John     artist
# 42499   1784           N03975  Burne-Jones, Sir Edward Coley, Bt     artist
# 42500   1785           N03976  Burne-Jones, Sir Edward Coley, Bt     artist
# 42501   1786           N03977  Burne-Jones, Sir Edward Coley, Bt     artist
# 42502   1787           N03978  Burne-Jones, Sir Edward Coley, Bt     artist
#
# ...

# %%
df.groupby('artist')

# %%
df.groupby('artist').transform('nunique')
# Out:
#        id  accession_number  artistRole  artistId  title  dateText  medium  \
# 0       4                 4           1         1      4         2       3
# 1       4                 4           1         1      4         2       3
# 2       4                 4           1         1      4         2       3
# 3       4                 4           1         1      4         2       3
# 4      94                94           1         1     91        29      22
# ...    ..               ...         ...       ...    ...       ...     ...
# 42498   4                 4           1         1      4         3       4
# 42499  97                97           1         1     86        34      22
# 42500  97                97           1         1     86        34      22
# 42501  97                97           1         1     86        34      22
# 42502  97                97           1         1     86        34      22
#
# ...

# %% [markdown]
# ## Filtering data

# %%
df.filter(items=['id','year'])
# Out:
#           id    year
# 0       1035     NaN
# 1       1036     NaN
# 2       1037  1785.0
# 3       1038     NaN
# 4       1039  1826.0
# ...      ...     ...
# 42498  11910  1865.0
# 42499   1784     NaN
# 42500   1785     NaN
# 42501   1786     NaN
# 42502   1787  1877.0
#
# [42503 rows x 2 columns]

# %% [markdown]
# ## like param are case sensitive avoid case sensitive we usr regular exp.

# %%
df.filter(regex="(?i)year")
# Out:
#          year  acquisitionYear
# 0         NaN           1922.0
# 1         NaN           1922.0
# 2      1785.0           1922.0
# 3         NaN           1922.0
# 4      1826.0           1919.0
# ...       ...              ...
# 42498  1865.0           1924.0
# 42499     NaN           1924.0
# 42500     NaN           1924.0
# 42501     NaN           1924.0
# 42502  1877.0           1924.0
#
# [42503 rows x 2 columns]

# %% [markdown]
# ### Droping data with pandas

# %%
df.drop(columns=['title'])
# Out:
#                                   artist
# 0                          Blake, Robert
# 1                          Blake, Robert
# 2                          Blake, Robert
# 3                          Blake, Robert
# 4                         Blake, William
# ...                                  ...
# 42498               Pinwell, George John
# 42499  Burne-Jones, Sir Edward Coley, Bt
# 42500  Burne-Jones, Sir Edward Coley, Bt
# 42501  Burne-Jones, Sir Edward Coley, Bt
# 42502  Burne-Jones, Sir Edward Coley, Bt
#
# [42503 rows x 1 columns]

# %%
df.head()
# Out:
#            artist                                              title
# 0   Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1   Blake, Robert  Two Drawings of Frightened Figures, Probably f...
# 2   Blake, Robert  The Preaching of Warning. Verso: An Old Man En...
# 3   Blake, Robert     Six Drawings of Figures with Outstretched Arms
# 4  Blake, William  The Circle of the Lustful: Francesca da Rimini...

# %% [markdown]
# ### Droping data on time of loading data

# %%
#df=pd.read_csv('artwork_sample.csv',usecols=['artist','title'])

# %% [markdown]
# ### Direct filtering with square bracket

# %%
df=pd.read_csv('artwork_sample.csv')
# Out:
# /root/anaconda3/envs/tensorflow/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df['id']
# Out:
# 0         1035
# 1         1036
# 2         1037
# 3         1038
# 4         1039
#          ...
# 42498    11910
# 42499     1784
# 42500     1785
# 42501     1786
# 42502     1787
# Name: id, Length: 42503, dtype: int64

# %%
df['id'][1]
# Out:
# 1036

# %% [markdown]
# ## Accessing row

# %%
df[1:5]
# Out:
#      id accession_number          artist artistRole  artistId  \
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                         medium  \
# 1                            Graphite on paper
# 2  Graphite on paper. Verso: graphite on paper
# 3                            Graphite on paper
# 4                      Line engraving on paper
#
# ...

# %%
df[1:5]['artist']
# Out:
# 1     Blake, Robert
# 2     Blake, Robert
# 3     Blake, Robert
# 4    Blake, William
# Name: artist, dtype: object

# %%
df[df.year>1920]['year']
# Out:
# 1025     1931.0
# 1026     1931.0
# 1027     1931.0
# 1028     1931.0
# 1029     1931.0
#           ...
# 42486    1923.0
# 42487    1924.0
# 42488    1924.0
# 42490    1923.0
# 42492    1923.0
# Name: year, Length: 1144, dtype: float64

# %% [markdown]
# ### Dealing with missing value
#    * Deal with bad data

# %%
pd.isna(df.loc[:'dateText'])
# Out:
#           id  accession_number  artist  artistRole  artistId  title  dateText  \
# 0      False             False   False       False     False  False      True
# 1      False             False   False       False     False  False      True
# 2      False             False   False       False     False  False     False
# 3      False             False   False       False     False  False      True
# 4      False             False   False       False     False  False     False
# ...      ...               ...     ...         ...       ...    ...       ...
# 42498  False             False   False       False     False  False     False
# 42499  False             False   False       False     False  False      True
# 42500  False             False   False       False     False  False      True
# 42501  False             False   False       False     False  False      True
# 42502  False             False   False       False     False  False     False
#
# ...

# %%
from numpy import nan

# %%
df.replace({'dateText':{'date not known':nan}},inplace=True)

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...                     NaN
# 1  Two Drawings of Frightened Figures, Probably f...                     NaN
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms                     NaN
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %%
df.loc[df.dateText=='date not known',['dateText']]=nan

# %%
df.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...                     NaN
# 1  Two Drawings of Frightened Figures, Probably f...                     NaN
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms                     NaN
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# ...

# %% [markdown]
# ## Drop Rows of data

# %%
df.shape
# Out:
# (42503, 20)

# %%
df.dropna()
# Out:
#           id accession_number             artist artistRole  artistId  \
# 1738   98171          AR00001         Katz, Alex     artist      1386
# 1739   98172          AR00002         Katz, Alex     artist      1386
# 1740   98173          AR00003         Katz, Alex     artist      1386
# 1741   98174          AR00004         Katz, Alex     artist      1386
# 1742   98175          AR00005         Katz, Alex     artist      1386
# 1743   98177          AR00006         Katz, Alex     artist      1386
# 1744   98178          AR00007         Katz, Alex     artist      1386
# 1747   98183          AR00010         Katz, Alex     artist      1386
# 1749   98185          AR00012         Katz, Alex     artist      1386
# 1751   98187          AR00014         Katz, Alex     artist      1386
# 1752   98189          AR00015         Katz, Alex     artist      1386
# 1753   98190          AR00016         Katz, Alex     artist      1386
# ...

# %%
df.dropna().shape
# Out:
# (42, 20)

# %%
df.dropna(how='all').shape
# Out:
# (42503, 20)

# %%
df.dropna(subset=['year','acquisitionYear'],how='all').shape
# Out:
# (42500, 20)

# %% [markdown]
# ## Dealing with dupicate value

# %%
df.drop_duplicates(subset=['artist'])
# Out:
#           id accession_number                             artist  \
# 0       1035           A00001                      Blake, Robert
# 4       1039           A00005                     Blake, William
# 49      1183           A00050                   Richmond, George
# 50      1505           A00051        British School 18th century
# 56      1695           A00057  Burne-Jones, Sir Edward Coley, Bt
# ...      ...              ...                                ...
# 42491  16116           N03959               Wheeler, Sir Charles
# 42492   1622           N03960                     Brown, Kellock
# 42493   7930           N03962                      Kettle, Tilly
# 42494   7063           N03967           Jackson, Alexander Young
# 42495    973           N03970                   Nicholson, Isaac
#
#           artistRole  artistId  \
# 0             artist        38
# 4             artist        39
# 49     attributed to       447
# 50            artist        59
# ...
